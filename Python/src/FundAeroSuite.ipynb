# %% [markdown]
# # FundAeroSuite

# %% [markdown]
# # use only to run solution of exercises with python solutions

# %%
#%matplotlib inline

#import mpld3

from IPython.display import display, Math, Latex
import numpy as np
import matplotlib.pylab as plt
from Book.Corrections import solution

#mpld3.enable_notebook()

# %% [markdown]
# # Help
#
# * define the list of exercises to solve :
#
#     -**single exercise** : solution([[chap_number, exercice_number]])
#
#         solution([[10,[5]]])
#
#     -**several exercises, several chapters**, write a list as
#
#         solution([ [8,[6,7]] , [9,[1,2]] ])

# %%
solution([[4,[6]]])
# Out:
# ************************* 	CHAPTER n° 4 	  *************************
#
# ___________________________________________________________________________
#
#            	Ch : 4 	 EXERCISE n° 6
# ___________________________________________________________________________
# # ************************************************************
# # Slots and flaps on a rectangular wing
# # ************************************************************
#
# use of a flap :
# length flap/chord                 : 0.200000
# theta angle                       : 53.130102 °
# Delta L                           : 5.426458e+04 N
# use of slat :
# length slat/chord                : 0.050000
# angle theta                       : 154.158067
# Delta L                           : -3.566552e+02 N
# use of flap :
# use of slat :
